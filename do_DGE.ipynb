# %% [markdown]
# ### Running DESeq2 and edgeR and calculating Bayes factors

# %%
import os

# More requirements: R, statmod, tidyverse, bioconductor, limma >>> edgeR, DESeq2
# http://bioconductor.org/install/
# https://bioconductor.org/packages/release/bioc/html/edgeR.html
# https://bioconductor.org/packages/release/bioc/html/DESeq2.html
# https://bioconductor.org/packages/release/bioc/html/limma.html

# %% [markdown]
# #### 100 boostrap iterations á #reps ∈ {3,6,12,20}

# %% [markdown]
# # Running edgeR

# %%
# 3 REPLICATES


for i in range(1,101):

    DATASET_NAME = f"3R_100/R3_{i}.csv"

    RESULTS_NAME = f"DGE_results/R3_{i}_edgeR.csv"

    os.system(f"Rscript Do_DGE_edgeR_R3.R {DATASET_NAME} {RESULTS_NAME} 0.0")

    print(f"Done {i}")
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6338"
# Done 1
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6381"
# Done 2
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6399"
# Done 3
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6376"
# Done 4
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6417"
# Done 5
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6372"
# Done 6
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6404"
# Done 7
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6385"
# Done 8
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6298"
# Done 9
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6365"
# Done 10
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6323"
# Done 11
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6414"
# Done 12
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6351"
# Done 13
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6328"
# Done 14
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6322"
# Done 15
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6343"
# Done 16
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6344"
# Done 17
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6382"
# Done 18
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6359"
# Done 19
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6390"
# Done 20
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6317"
# Done 21
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6370"
# Done 22
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6378"
# Done 23
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6311"
# Done 24
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6335"
# Done 25
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6338"
# Done 26
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6377"
# Done 27
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6348"
# Done 28
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6358"
# Done 29
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6347"
# Done 30
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6356"
# Done 31
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6345"
# Done 32
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6359"
# Done 33
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6371"
# Done 34
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6368"
# Done 35
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6365"
# Done 36
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6330"
# Done 37
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6375"
# Done 38
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6369"
# Done 39
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6337"
# Done 40
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6387"
# Done 41
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6345"
# Done 42
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6362"
# Done 43
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6381"
# Done 44
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6316"
# Done 45
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6330"
# Done 46
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6348"
# Done 47
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6344"
# Done 48
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6366"
# Done 49
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ...
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6345"
# Done 84
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6356"
# Done 85
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6327"
# Done 86
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6351"
# Done 87
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6354"
# Done 88
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6380"
# Done 89
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6369"
# Done 90
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6340"
# Done 91
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6314"
# Done 92
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6319"
# Done 93
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6325"
# Done 94
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6345"
# Done 95
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6343"
# Done 96
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6339"
# Done 97
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6336"
# Done 98
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6368"
# Done 99
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6378"
# Done 100

# %%
# 6 REPLICATES


for i in range(1,101):

    DATASET_NAME = f"6R_100/R6_{i}.csv"

    RESULTS_NAME = f"DGE_results/R6_{i}_edgeR.csv"

    os.system(f"Rscript Do_DGE_edgeR_R6.R {DATASET_NAME} {RESULTS_NAME} 0.0")

    print(f"Done {i}")
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6320"
# Done 1
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6259"
# Done 2
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6261"
# Done 3
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6281"
# Done 4
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6287"
# Done 5
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6275"
# Done 6
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6273"
# Done 7
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6256"
# Done 8
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6295"
# Done 9
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6262"
# Done 10
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6295"
# Done 11
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6273"
# Done 12
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6302"
# Done 13
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6289"
# Done 14
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6302"
# Done 15
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6298"
# Done 16
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6285"
# Done 17
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6292"
# Done 18
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6307"
# Done 19
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6293"
# Done 20
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6270"
# Done 21
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6314"
# Done 22
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6250"
# Done 23
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6282"
# Done 24
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6319"
# Done 25
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6297"
# Done 26
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6277"
# Done 27
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6275"
# Done 28
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6300"
# Done 29
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6256"
# Done 30
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6277"
# Done 31
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6288"
# Done 32
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6308"
# Done 33
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6295"
# Done 34
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6285"
# Done 35
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6280"
# Done 36
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6295"
# Done 37
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6276"
# Done 38
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6282"
# Done 39
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6294"
# Done 40
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6305"
# Done 41
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6259"
# Done 42
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6328"
# Done 43
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6278"
# Done 44
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6288"
# Done 45
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6270"
# Done 46
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6272"
# Done 47
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6288"
# Done 48
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6274"
# Done 49
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ...
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6275"
# Done 84
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6260"
# Done 85
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6256"
# Done 86
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6250"
# Done 87
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6279"
# Done 88
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6314"
# Done 89
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6271"
# Done 90
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6282"
# Done 91
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6287"
# Done 92
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6308"
# Done 93
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6283"
# Done 94
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6250"
# Done 95
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6281"
# Done 96
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6306"
# Done 97
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6270"
# Done 98
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6277"
# Done 99
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6306"
# Done 100

# %%
# 12 REPLICATES


for i in range(1,101):

    DATASET_NAME = f"12R_100/R12_{i}.csv"

    RESULTS_NAME = f"DGE_results/R12_{i}_edgeR.csv"

    os.system(f"Rscript Do_DGE_edgeR_R12.R {DATASET_NAME} {RESULTS_NAME} 0.0")

    print(f"Done {i}")
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6260"
# Done 1
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6227"
# Done 2
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6259"
# Done 3
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6237"
# Done 4
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6236"
# Done 5
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6250"
# Done 6
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6232"
# Done 7
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6230"
# Done 8
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6239"
# Done 9
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6221"
# Done 10
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6230"
# Done 11
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6222"
# Done 12
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6242"
# Done 13
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6251"
# Done 14
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6222"
# Done 15
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6258"
# Done 16
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6248"
# Done 17
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6218"
# Done 18
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6212"
# Done 19
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6241"
# Done 20
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6219"
# Done 21
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6266"
# Done 22
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6228"
# Done 23
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6237"
# Done 24
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6259"
# Done 25
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6226"
# Done 26
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6231"
# Done 27
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6225"
# Done 28
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6227"
# Done 29
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6236"
# Done 30
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6218"
# Done 31
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6234"
# Done 32
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6211"
# Done 33
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6219"
# Done 34
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6231"
# Done 35
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6244"
# Done 36
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6226"
# Done 37
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6232"
# Done 38
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6251"
# Done 39
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6210"
# Done 40
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6237"
# Done 41
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6228"
# Done 42
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6248"
# Done 43
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6254"
# Done 44
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6240"
# Done 45
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6217"
# Done 46
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6233"
# Done 47
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6224"
# Done 48
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6220"
# Done 49
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ...
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6226"
# Done 84
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6210"
# Done 85
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6242"
# Done 86
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6239"
# Done 87
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6251"
# Done 88
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6247"
# Done 89
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6232"
# Done 90
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6249"
# Done 91
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6222"
# Done 92
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6230"
# Done 93
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6247"
# Done 94
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6246"
# Done 95
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6253"
# Done 96
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6254"
# Done 97
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6237"
# Done 98
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6239"
# Done 99
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6231"
# Done 100

# %%
# 20 REPLICATES


for i in range(1,101):

    DATASET_NAME = f"20R_100/R20_{i}.csv"

    RESULTS_NAME = f"DGE_results/R20_{i}_edgeR.csv"

    os.system(f"Rscript Do_DGE_edgeR_R20.R {DATASET_NAME} {RESULTS_NAME} 0.0")

    print(f"Done {i}")
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6197"
# Done 1
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6195"
# Done 2
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6186"
# Done 3
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6185"
# Done 4
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6205"
# Done 5
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6186"
# Done 6
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6197"
# Done 7
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6198"
# Done 8
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6182"
# Done 9
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6209"
# Done 10
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6221"
# Done 11
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6196"
# Done 12
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6210"
# Done 13
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6213"
# Done 14
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6187"
# Done 15
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6195"
# Done 16
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6181"
# Done 17
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6205"
# Done 18
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6184"
# Done 19
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6188"
# Done 20
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6192"
# Done 21
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6194"
# Done 22
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6208"
# Done 23
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6191"
# Done 24
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6205"
# Done 25
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6194"
# Done 26
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6190"
# Done 27
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6210"
# Done 28
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6211"
# Done 29
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6194"
# Done 30
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6204"
# Done 31
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6205"
# Done 32
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6202"
# Done 33
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6209"
# Done 34
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6197"
# Done 35
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6202"
# Done 36
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6194"
# Done 37
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6203"
# Done 38
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6191"
# Done 39
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6196"
# Done 40
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6185"
# Done 41
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6204"
# Done 42
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6191"
# Done 43
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6184"
# Done 44
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6200"
# Done 45
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6181"
# Done 46
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6180"
# Done 47
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6191"
# Done 48
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6205"
# Done 49
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ...
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6205"
# Done 84
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6192"
# Done 85
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6200"
# Done 86
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6203"
# Done 87
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6188"
# Done 88
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6205"
# Done 89
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6210"
# Done 90
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6187"
# Done 91
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6198"
# Done 92
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6191"
# Done 93
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6194"
# Done 94
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6194"
# Done 95
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6200"
# Done 96
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6175"
# Done 97
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6190"
# Done 98
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6207"
# Done 99
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6206"
# Done 100

# %%
# ALL REPLICATES


DATASET_NAME = f"RALL.csv"

RESULTS_NAME = f"DGE_results/RALL_edgeR.csv"

os.system(f"Rscript Do_DGE_edgeR_RALL.R {DATASET_NAME} {RESULTS_NAME} 0.0")

print(f"Done ALL")
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.3     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Lade nötiges Paket: limma
#
# Attache Paket: ‘data.table’
#
# Die folgenden Objekte sind maskiert von ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     between, first, last
#
# Das folgende Objekt ist maskiert ‘package:purrr’:
#
#     transpose
# [1] "Row count before CPM filtering = 7126"
# [1] "Row count before CPM filtering = 6150"
# Done ALL

# %% [markdown]
# # Running DESeq2

# %%
# 3 REPLICATES


for i in range(1,101):

    DATASET_NAME = f"3R_100/R3_{i}.csv"

    METADATA_NAME = f"3R_100/R3_{i}_meta.txt"

    RESULTS_NAME = f"DGE_results/R3_{i}_DESeq2.csv"

    os.system(f"Rscript Do_DGE_DESeq2.R {DATASET_NAME} {METADATA_NAME} {RESULTS_NAME}")

    print(f"Done {i}")
# Out:
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 1
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 2
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 3
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 4
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 5
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 6
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 7
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 8
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 9
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 10
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 11
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 12
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 13
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 14
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 15
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 16
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
# ...
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 95
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 96
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 97
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 98
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 99
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Done 100
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors

# %%
# 6 REPLICATES


for i in range(1,101):

    DATASET_NAME = f"6R_100/R6_{i}.csv"

    METADATA_NAME = f"6R_100/R6_{i}_meta.txt"

    RESULTS_NAME = f"DGE_results/R6_{i}_DESeq2.csv"

    os.system(f"Rscript Do_DGE_DESeq2.R {DATASET_NAME} {METADATA_NAME} {RESULTS_NAME}")

    print(f"Done {i}")
# Out:
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 1
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 2
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 3
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 4
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 5
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 6
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 7
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 8
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 9
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 10
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 11
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 12
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 13
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 14
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 15
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 16
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
# ...
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 95
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 96
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 97
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 98
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 99
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Done 100
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors

# %%
# 12 REPLICATES


for i in range(1,101):

    DATASET_NAME = f"12R_100/R12_{i}.csv"

    METADATA_NAME = f"12R_100/R12_{i}_meta.txt"

    RESULTS_NAME = f"DGE_results/R12_{i}_DESeq2.csv"

    os.system(f"Rscript Do_DGE_DESeq2.R {DATASET_NAME} {METADATA_NAME} {RESULTS_NAME}")

    print(f"Done {i}")
# Out:
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# -- replacing outliers and refitting for 4 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
# estimating dispersions
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 1
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# -- replacing outliers and refitting for 1 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
# estimating dispersions
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 2
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 3
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# -- replacing outliers and refitting for 1 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
# estimating dispersions
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 4
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 5
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# -- replacing outliers and refitting for 2 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
# estimating dispersions
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 6
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 7
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 8
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# -- replacing outliers and refitting for 1 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
# estimating dispersions
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 9
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# -- replacing outliers and refitting for 6 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
# estimating dispersions
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 10
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# -- replacing outliers and refitting for 1 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
# estimating dispersions
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 11
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# -- replacing outliers and refitting for 2 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
# estimating dispersions
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 12
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 13
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# -- replacing outliers and refitting for 4 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
# estimating dispersions
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 14
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# -- replacing outliers and refitting for 3 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
# estimating dispersions
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 15
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# -- replacing outliers and refitting for 1 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
# estimating dispersions
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 16
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# ...
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# -- replacing outliers and refitting for 1 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
# estimating dispersions
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 95
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# -- replacing outliers and refitting for 1 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
# estimating dispersions
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 96
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 97
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# -- replacing outliers and refitting for 3 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
# estimating dispersions
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 98
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# -- replacing outliers and refitting for 7 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
# estimating dispersions
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 99
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# -- replacing outliers and refitting for 1 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
# estimating dispersions
# fitting model and testing
# Done 100
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors

# %%
# 20 REPLICATES


for i in range(1,101):

    DATASET_NAME = f"20R_100/R20_{i}.csv"

    METADATA_NAME = f"20R_100/R20_{i}_meta.txt"

    RESULTS_NAME = f"DGE_results/R20_{i}_DESeq2.csv"

    os.system(f"Rscript Do_DGE_DESeq2.R {DATASET_NAME} {METADATA_NAME} {RESULTS_NAME}")

    print(f"Done {i}")
# Out:
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# -- replacing outliers and refitting for 3 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
# estimating dispersions
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 1
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# -- replacing outliers and refitting for 2 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
# estimating dispersions
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 2
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# -- replacing outliers and refitting for 1 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
# estimating dispersions
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 3
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# -- replacing outliers and refitting for 1 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
# estimating dispersions
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 4
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# -- replacing outliers and refitting for 1 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
# estimating dispersions
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 5
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# -- replacing outliers and refitting for 5 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
# estimating dispersions
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 6
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 7
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# -- replacing outliers and refitting for 1 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
# estimating dispersions
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 8
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 9
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# -- replacing outliers and refitting for 6 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
# estimating dispersions
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 10
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# -- replacing outliers and refitting for 3 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
# estimating dispersions
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 11
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 12
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# -- replacing outliers and refitting for 5 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
# estimating dispersions
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 13
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# -- replacing outliers and refitting for 7 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
# estimating dispersions
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 14
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# -- replacing outliers and refitting for 3 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
# estimating dispersions
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 15
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# -- replacing outliers and refitting for 4 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
# estimating dispersions
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 16
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
# ...
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 95
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# -- replacing outliers and refitting for 1 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
# estimating dispersions
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 96
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# -- replacing outliers and refitting for 3 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
# estimating dispersions
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 97
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# -- replacing outliers and refitting for 1 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
# estimating dispersions
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 98
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# -- replacing outliers and refitting for 3 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
# estimating dispersions
# fitting model and testing
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors
# Done 99
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# -- replacing outliers and refitting for 3 genes
# -- DESeq argument 'minReplicatesForReplace' = 7
# -- original counts are preserved in counts(dds)
# estimating dispersions
# fitting model and testing
# Done 100
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors

# %%
# all reps


DATASET_NAME = f"RALL.csv"

METADATA_NAME = f"RALL_meta.txt"

RESULTS_NAME = f"DGE_results/RALL_DESeq2.csv"

os.system(f"Rscript Do_DGE_DESeq2.R {DATASET_NAME} {METADATA_NAME} {RESULTS_NAME}")

print(f"Done ALL")
# Out:
# Lade nötiges Paket: S4Vectors
# Lade nötiges Paket: stats4
# Lade nötiges Paket: BiocGenerics
#
# Attache Paket: ‘BiocGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, aperm, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
# Attache Paket: ‘S4Vectors’
#
# Das folgende Objekt ist maskiert ‘package:utils’:
#
#     findMatches
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
#     I, expand.grid, unname
#
# Lade nötiges Paket: IRanges
# Lade nötiges Paket: GenomicRanges
# Lade nötiges Paket: GenomeInfoDb
# Lade nötiges Paket: SummarizedExperiment
# Lade nötiges Paket: MatrixGenerics
# Lade nötiges Paket: matrixStats
#
# Attache Paket: ‘MatrixGenerics’
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Lade nötiges Paket: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attache Paket: ‘Biobase’
#
# Das folgende Objekt ist maskiert ‘package:MatrixGenerics’:
#
#     rowMedians
#
# Die folgenden Objekte sind maskiert von ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# estimating size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Done ALL
# Warnmeldung:
# In DESeqDataSet(se, design = design, ignoreRank) :
#   some variables in design formula are characters, converting to factors

# %% [markdown]
# # bayexpress

# %%
import pandas as pd
import numpy as np
from numpy import random
import scipy.special as sc
import matplotlib as m
import os

# %%
# calculating Bayes factors
def get_BF(N_1, n_1, N_2, n_2):

    return (sc.betaln( u_1 + n_1, u_2 + N_1 - n_1) + sc.betaln( u_1 + n_2, u_2 + N_2 - n_2) - sc.betaln( u_1 + n_1 + n_2, u_2 + N_1 - n_1 + N_2 - n_2)) / np.log(10) 


# ratio of expression 
# calculating log fold change
def get_FC(N_1, n_1, N_2, n_2):
    rate_1 = (u_1 + n_1) / (u_2 + N_1 - n_1)
    rate_2 = (u_1 + n_2) / (u_2 + N_2 - n_2)

    return np.log2(rate_2 / rate_1)

# setting the priors to flat prios
u_1 = 1
u_2 = 1

# %%
# all reps

in_data = pd.read_csv(f"RALL.csv")

out_data = pd.DataFrame({'genes': in_data.genes})

n_1 = in_data.iloc[:,1:43].sum(axis=1)
n_2 = in_data.iloc[:,43:].sum(axis=1)

N_1 = in_data.iloc[:,1:43].sum(axis=1).sum()
N_2 = in_data.iloc[:,43:].sum(axis=1).sum()

out_data['BF'] = get_BF(N_1, n_1, N_2, n_2)
out_data['FC'] = get_FC(N_1, n_1, N_2, n_2)

out_data.to_csv(f"DGE_results/RALL_bayexpress.csv")

# %%
# 3 REPLICATES

# summing up over replicates


for i in range(1,101):

    in_data = pd.read_csv(f"3R_100/R3_{i}.csv")

    out_data = pd.DataFrame({'locus_name': in_data.locus_name})

    n_1 = in_data.iloc[:,1:4].sum(axis=1)
    n_2 = in_data.iloc[:,4:].sum(axis=1)

    N_1 = in_data.iloc[:,1:4].sum(axis=1).sum()
    N_2 = in_data.iloc[:,4:].sum(axis=1).sum()

    out_data['BF'] = get_BF(N_1, n_1, N_2, n_2)
    out_data['FC'] = get_FC(N_1, n_1, N_2, n_2)

    out_data.to_csv(f"DGE_results/R3_{i}_bayexpress.csv")

    print(f"Done {i}")
# Out:
# Done 1
# Done 2
# Done 3
# Done 4
# Done 5
# Done 6
# Done 7
# Done 8
# Done 9
# Done 10
# Done 11
# Done 12
# Done 13
# Done 14
# Done 15
# Done 16
# Done 17
# Done 18
# Done 19
# Done 20
# Done 21
# Done 22
# Done 23
# Done 24
# Done 25
# Done 26
# Done 27
# Done 28
# Done 29
# Done 30
# Done 31
# Done 32
# Done 33
# Done 34
# Done 35
# Done 36
# Done 37
# Done 38
# Done 39
# Done 40
# Done 41
# Done 42
# Done 43
# Done 44
# Done 45
# Done 46
# Done 47
# Done 48
# Done 49
# Done 50
# Done 51
# Done 52
# Done 53
# Done 54
# Done 55
# Done 56
# Done 57
# Done 58
# Done 59
# Done 60
# Done 61
# Done 62
# Done 63
# Done 64
# Done 65
# Done 66
# Done 67
# Done 68
# Done 69
# Done 70
# Done 71
# Done 72
# Done 73
# Done 74
# Done 75
# Done 76
# Done 77
# Done 78
# Done 79
# Done 80
# Done 81
# Done 82
# Done 83
# Done 84
# Done 85
# Done 86
# Done 87
# Done 88
# Done 89
# Done 90
# Done 91
# Done 92
# Done 93
# Done 94
# Done 95
# Done 96
# Done 97
# Done 98
# Done 99
# Done 100

# %%
# 6 REPLICATES

# summing up over replicates


for i in range(1,101):

    in_data = pd.read_csv(f"6R_100/R6_{i}.csv")

    out_data = pd.DataFrame({'locus_name': in_data.locus_name})

    n_1 = in_data.iloc[:,1:7].sum(axis=1)
    n_2 = in_data.iloc[:,7:].sum(axis=1)

    N_1 = in_data.iloc[:,1:7].sum(axis=1).sum()
    N_2 = in_data.iloc[:,7:].sum(axis=1).sum()

    out_data['BF'] = get_BF(N_1, n_1, N_2, n_2)
    out_data['FC'] = get_FC(N_1, n_1, N_2, n_2)

    out_data.to_csv(f"DGE_results/R6_{i}_bayexpress.csv")

    print(f"Done {i}")
# Out:
# Done 1
# Done 2
# Done 3
# Done 4
# Done 5
# Done 6
# Done 7
# Done 8
# Done 9
# Done 10
# Done 11
# Done 12
# Done 13
# Done 14
# Done 15
# Done 16
# Done 17
# Done 18
# Done 19
# Done 20
# Done 21
# Done 22
# Done 23
# Done 24
# Done 25
# Done 26
# Done 27
# Done 28
# Done 29
# Done 30
# Done 31
# Done 32
# Done 33
# Done 34
# Done 35
# Done 36
# Done 37
# Done 38
# Done 39
# Done 40
# Done 41
# Done 42
# Done 43
# Done 44
# Done 45
# Done 46
# Done 47
# Done 48
# Done 49
# Done 50
# Done 51
# Done 52
# Done 53
# Done 54
# Done 55
# Done 56
# Done 57
# Done 58
# Done 59
# Done 60
# Done 61
# Done 62
# Done 63
# Done 64
# Done 65
# Done 66
# Done 67
# Done 68
# Done 69
# Done 70
# Done 71
# Done 72
# Done 73
# Done 74
# Done 75
# Done 76
# Done 77
# Done 78
# Done 79
# Done 80
# Done 81
# Done 82
# Done 83
# Done 84
# Done 85
# Done 86
# Done 87
# Done 88
# Done 89
# Done 90
# Done 91
# Done 92
# Done 93
# Done 94
# Done 95
# Done 96
# Done 97
# Done 98
# Done 99
# Done 100

# %%
# 12 REPLICATES

# summing up over replicates


for i in range(1,101):

    in_data = pd.read_csv(f"12R_100/R12_{i}.csv")

    out_data = pd.DataFrame({'locus_name': in_data.locus_name})

    n_1 = in_data.iloc[:,1:13].sum(axis=1)
    n_2 = in_data.iloc[:,13:].sum(axis=1)

    N_1 = in_data.iloc[:,1:13].sum(axis=1).sum()
    N_2 = in_data.iloc[:,13:].sum(axis=1).sum()

    out_data['BF'] = get_BF(N_1, n_1, N_2, n_2)
    out_data['FC'] = get_FC(N_1, n_1, N_2, n_2)

    out_data.to_csv(f"DGE_results/R12_{i}_bayexpress.csv")

    print(f"Done {i}")
# Out:
# Done 1
# Done 2
# Done 3
# Done 4
# Done 5
# Done 6
# Done 7
# Done 8
# Done 9
# Done 10
# Done 11
# Done 12
# Done 13
# Done 14
# Done 15
# Done 16
# Done 17
# Done 18
# Done 19
# Done 20
# Done 21
# Done 22
# Done 23
# Done 24
# Done 25
# Done 26
# Done 27
# Done 28
# Done 29
# Done 30
# Done 31
# Done 32
# Done 33
# Done 34
# Done 35
# Done 36
# Done 37
# Done 38
# Done 39
# Done 40
# Done 41
# Done 42
# Done 43
# Done 44
# Done 45
# Done 46
# Done 47
# Done 48
# Done 49
# Done 50
# Done 51
# Done 52
# Done 53
# Done 54
# Done 55
# Done 56
# Done 57
# Done 58
# Done 59
# Done 60
# Done 61
# Done 62
# Done 63
# Done 64
# Done 65
# Done 66
# Done 67
# Done 68
# Done 69
# Done 70
# Done 71
# Done 72
# Done 73
# Done 74
# Done 75
# Done 76
# Done 77
# Done 78
# Done 79
# Done 80
# Done 81
# Done 82
# Done 83
# Done 84
# Done 85
# Done 86
# Done 87
# Done 88
# Done 89
# Done 90
# Done 91
# Done 92
# Done 93
# Done 94
# Done 95
# Done 96
# Done 97
# Done 98
# Done 99
# Done 100

# %%
# 20 REPLICATES

# summing up over replicates


for i in range(1,101):

    in_data = pd.read_csv(f"20R_100/R20_{i}.csv")

    out_data = pd.DataFrame({'locus_name': in_data.locus_name})

    n_1 = in_data.iloc[:,1:21].sum(axis=1)
    n_2 = in_data.iloc[:,21:].sum(axis=1)

    N_1 = in_data.iloc[:,1:21].sum(axis=1).sum()
    N_2 = in_data.iloc[:,21:].sum(axis=1).sum()

    out_data['BF'] = get_BF(N_1, n_1, N_2, n_2)
    out_data['FC'] = get_FC(N_1, n_1, N_2, n_2)

    out_data.to_csv(f"DGE_results/R20_{i}_bayexpress.csv")

    print(f"Done {i}")
# Out:
# Done 1
# Done 2
# Done 3
# Done 4
# Done 5
# Done 6
# Done 7
# Done 8
# Done 9
# Done 10
# Done 11
# Done 12
# Done 13
# Done 14
# Done 15
# Done 16
# Done 17
# Done 18
# Done 19
# Done 20
# Done 21
# Done 22
# Done 23
# Done 24
# Done 25
# Done 26
# Done 27
# Done 28
# Done 29
# Done 30
# Done 31
# Done 32
# Done 33
# Done 34
# Done 35
# Done 36
# Done 37
# Done 38
# Done 39
# Done 40
# Done 41
# Done 42
# Done 43
# Done 44
# Done 45
# Done 46
# Done 47
# Done 48
# Done 49
# Done 50
# Done 51
# Done 52
# Done 53
# Done 54
# Done 55
# Done 56
# Done 57
# Done 58
# Done 59
# Done 60
# Done 61
# Done 62
# Done 63
# Done 64
# Done 65
# Done 66
# Done 67
# Done 68
# Done 69
# Done 70
# Done 71
# Done 72
# Done 73
# Done 74
# Done 75
# Done 76
# Done 77
# Done 78
# Done 79
# Done 80
# Done 81
# Done 82
# Done 83
# Done 84
# Done 85
# Done 86
# Done 87
# Done 88
# Done 89
# Done 90
# Done 91
# Done 92
# Done 93
# Done 94
# Done 95
# Done 96
# Done 97
# Done 98
# Done 99
# Done 100

# %% [markdown]
# ### Control experiment ... what if we only use the WT in the bootstrapping?

# %%
# assuming a flat prior (for now?)
u_1 = 1
u_2 = 1

# calculating Bayes factors

def get_nBF(data):
    # this range is irrelevant if we want to do all 
    k = len(data.columns)

    evidence2 = np.full(len(data), 0)

    # iterating over j until k
    for col in data.columns[1:k]: 
        n_j = data[col]
        # print(n_j, 'n_j')
        N_j = sum(data[col])
        # print(N_j, 'N_j')
        evidence2 = evidence2 + sc.betaln(u_1 + n_j, u_2 + N_j - n_j)

    N = sum(data.iloc[:,1:k].sum(axis=0, numeric_only=True))
    n_i = data.iloc[:,1:k].sum(axis=1, numeric_only=True)

    # print(n_i, 'n_i')
    # print(N, 'N')

    evidence1 = sc.betaln( u_1 + n_i, u_2 + N - n_i)

    return (evidence2 - evidence1) / np.log(10)

# %%
# 3 REPLICATES
# CONTROL EXPERIMENT

# summing up over replicates


for i in range(1,101):

    in_data = pd.read_csv(f"6R_100/R6_{i}.csv")

    out_data = pd.DataFrame({'locus_name': in_data.locus_name})

    n_1 = in_data.iloc[:,1:4].sum(axis=1)
    n_2 = in_data.iloc[:,4:7].sum(axis=1)

    N_1 = in_data.iloc[:,1:4].sum(axis=1).sum()
    N_2 = in_data.iloc[:,4:7].sum(axis=1).sum()

    out_data['BF'] = get_BF(N_1, n_1, N_2, n_2)
    out_data['FC'] = get_FC(N_1, n_1, N_2, n_2)

    out_data['nBF_1'] = get_nBF(in_data.iloc[:,1:4])
    out_data['nBF_2'] = get_nBF(in_data.iloc[:,4:7])

    out_data.to_csv(f"DGE_results/CONTROL_R3_{i}_bayexpress.csv")

    print(f"Done {i}")
# Out:
# Done 1
# Done 2
# Done 3
# Done 4
# Done 5
# Done 6
# Done 7
# Done 8
# Done 9
# Done 10
# Done 11
# Done 12
# Done 13
# Done 14
# Done 15
# Done 16
# Done 17
# Done 18
# Done 19
# Done 20
# Done 21
# Done 22
# Done 23
# Done 24
# Done 25
# Done 26
# Done 27
# Done 28
# Done 29
# Done 30
# Done 31
# Done 32
# Done 33
# Done 34
# Done 35
# Done 36
# Done 37
# Done 38
# Done 39
# Done 40
# Done 41
# Done 42
# Done 43
# Done 44
# Done 45
# Done 46
# Done 47
# Done 48
# Done 49
# Done 50
# Done 51
# Done 52
# Done 53
# Done 54
# Done 55
# Done 56
# Done 57
# Done 58
# Done 59
# Done 60
# Done 61
# Done 62
# Done 63
# Done 64
# Done 65
# Done 66
# Done 67
# Done 68
# Done 69
# Done 70
# Done 71
# Done 72
# Done 73
# Done 74
# Done 75
# Done 76
# Done 77
# Done 78
# Done 79
# Done 80
# Done 81
# Done 82
# Done 83
# Done 84
# Done 85
# Done 86
# Done 87
# Done 88
# Done 89
# Done 90
# Done 91
# Done 92
# Done 93
# Done 94
# Done 95
# Done 96
# Done 97
# Done 98
# Done 99
# Done 100

# %%
# 10 REPLICATES
# CONTROL EXPERIMENT

# summing up over replicates


for i in range(1,101):

    in_data = pd.read_csv(f"20R_100/R20_{i}.csv")

    out_data = pd.DataFrame({'locus_name': in_data.locus_name})

    n_1 = in_data.iloc[:,1:11].sum(axis=1)
    n_2 = in_data.iloc[:,11:21].sum(axis=1)

    N_1 = in_data.iloc[:,1:11].sum(axis=1).sum()
    N_2 = in_data.iloc[:,11:21].sum(axis=1).sum()

    out_data['BF'] = get_BF(N_1, n_1, N_2, n_2)
    out_data['FC'] = get_FC(N_1, n_1, N_2, n_2)

    out_data['nBF_1'] = get_nBF(in_data.iloc[:,1:4])
    out_data['nBF_2'] = get_nBF(in_data.iloc[:,4:7])

    out_data.to_csv(f"DGE_results/CONTROL_R10_{i}_bayexpress.csv")

    print(f"Done {i}")
# Out:
# Done 1
# Done 2
# Done 3
# Done 4
# Done 5
# Done 6
# Done 7
# Done 8
# Done 9
# Done 10
# Done 11
# Done 12
# Done 13
# Done 14
# Done 15
# Done 16
# Done 17
# Done 18
# Done 19
# Done 20
# Done 21
# Done 22
# Done 23
# Done 24
# Done 25
# Done 26
# Done 27
# Done 28
# Done 29
# Done 30
# Done 31
# Done 32
# Done 33
# Done 34
# Done 35
# Done 36
# Done 37
# Done 38
# Done 39
# Done 40
# Done 41
# Done 42
# Done 43
# Done 44
# Done 45
# Done 46
# Done 47
# Done 48
# Done 49
# Done 50
# Done 51
# Done 52
# Done 53
# Done 54
# Done 55
# Done 56
# Done 57
# Done 58
# Done 59
# Done 60
# Done 61
# Done 62
# Done 63
# Done 64
# Done 65
# Done 66
# Done 67
# Done 68
# Done 69
# Done 70
# Done 71
# Done 72
# Done 73
# Done 74
# Done 75
# Done 76
# Done 77
# Done 78
# Done 79
# Done 80
# Done 81
# Done 82
# Done 83
# Done 84
# Done 85
# Done 86
# Done 87
# Done 88
# Done 89
# Done 90
# Done 91
# Done 92
# Done 93
# Done 94
# Done 95
# Done 96
# Done 97
# Done 98
# Done 99
# Done 100
