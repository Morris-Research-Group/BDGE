# %%
import pandas as pd
import numpy as np
import scipy.special as sc
import matplotlib as m
import matplotlib.pyplot as plt

# %%
# control experiment

# 10 reps, 100 iterations 
# samples from ONLY WT!

# %%
# all bayexpress results
# 10 replicates

CONTROL_R10_bayexpress_FC0 = pd.read_csv(f'DGE_results/CONTROL_R10_1_bayexpress.csv').iloc[:,1:2]
CONTROL_R10_bayexpress_FC1 = pd.read_csv(f'DGE_results/CONTROL_R10_1_bayexpress.csv').iloc[:,1:2]
CONTROL_R10_bayexpress_FC2 = pd.read_csv(f'DGE_results/CONTROL_R10_1_bayexpress.csv').iloc[:,1:2]

for i in range(1,101):

    data = pd.read_csv(f'DGE_results/CONTROL_R10_{i}_bayexpress.csv').iloc[:,1:]

    # criteria 0 for significance: (BF > 1) & (abs(FC) > 0)
    CONTROL_R10_bayexpress_FC0[f'{i}'] = (data.BF > 1) & (abs(data.FC) > 0)

    # criteria 1 for significance: (BF > 1) & (abs(FC) > 1)
    CONTROL_R10_bayexpress_FC1[f'{i}'] = (data.BF > 1) & (abs(data.FC) > 1)

    # criteria 2 for significance: (BF > 1) & (abs(FC) > 2)
    CONTROL_R10_bayexpress_FC2[f'{i}'] = (data.BF > 1) & (abs(data.FC) > 2)

CONTROL_R10_bayexpress_FC0['Ntrue'] = [(CONTROL_R10_bayexpress_FC0.iloc[i].value_counts().get(True, 0)) for i in range(len(CONTROL_R10_bayexpress_FC0))]

CONTROL_R10_bayexpress_FC1['Ntrue'] = [(CONTROL_R10_bayexpress_FC1.iloc[i].value_counts().get(True, 0)) for i in range(len(CONTROL_R10_bayexpress_FC1))]

CONTROL_R10_bayexpress_FC2['Ntrue'] = [(CONTROL_R10_bayexpress_FC2.iloc[i].value_counts().get(True, 0)) for i in range(len(CONTROL_R10_bayexpress_FC2))]

display(CONTROL_R10_bayexpress_FC0)
display(CONTROL_R10_bayexpress_FC1)
display(CONTROL_R10_bayexpress_FC2)
# Out:
# /var/folders/4r/_n71yczn7dbf4gx1wd510hvml1_mw7/T/ipykernel_25410/3811897209.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   CONTROL_R10_bayexpress_FC0[f'{i}'] = (data.BF > 1) & (abs(data.FC) > 0)
# /var/folders/4r/_n71yczn7dbf4gx1wd510hvml1_mw7/T/ipykernel_25410/3811897209.py:16: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   CONTROL_R10_bayexpress_FC1[f'{i}'] = (data.BF > 1) & (abs(data.FC) > 1)
# /var/folders/4r/_n71yczn7dbf4gx1wd510hvml1_mw7/T/ipykernel_25410/3811897209.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   CONTROL_R10_bayexpress_FC2[f'{i}'] = (data.BF > 1) & (abs(data.FC) > 2)
# /var/folders/4r/_n71yczn7dbf4gx1wd510hvml1_mw7/T/ipykernel_25410/3811897209.py:21: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   CONTROL_R10_bayexpress_FC0['Ntrue'] = [(CONTROL_R10_bayexpress_FC0.iloc[i].value_counts().get(True, 0)) for i in range(len(CONTROL_R10_bayexpress_FC0))]
# /var/folders/4r/_n71yczn7dbf4gx1wd510hvml1_mw7/T/ipykernel_25410/3811897209.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   CONTROL_R10_bayexpress_FC1['Ntrue'] = [(CONTROL_R10_bayexpress_FC1.iloc[i].value_counts().get(True, 0)) for i in range(len(CONTROL_R10_bayexpress_FC1))]
# /var/folders/4r/_n71yczn7dbf4gx1wd510hvml1_mw7/T/ipykernel_25410/3811897209.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   CONTROL_R10_bayexpress_FC2['Ntrue'] = [(CONTROL_R10_bayexpress_FC2.iloc[i].value_counts().get(True, 0)) for i in range(len(CONTROL_R10_bayexpress_FC2))]
#      locus_name      1      2      3      4      5      6      7      8  \
# 0      15S_rRNA  False   True  False  False  False  False  False  False
# 1      21S_rRNA  False   True  False   True   True  False   True  False
# 2          HRA1  False  False  False  False  False  False  False  False
# 3          ICR1  False  False  False  False  False  False  False  False
# 4          LSR1  False   True  False  False  False  False  False  False
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 7121  tY(GUA)J2  False  False  False  False  False  False  False  False
# 7122  tY(GUA)M1  False  False  False  False  False  False  False  False
# 7123  tY(GUA)M2  False  False  False  False  False  False  False  False
# 7124   tY(GUA)O  False  False  False  False  False  False  False  False
# 7125   tY(GUA)Q  False  False  False  False  False  False  False  False
#
#           9  ...     92     93     94     95     96     97     98     99  \
# 0     False  ...  False   True  False  False  False  False  False  False
# 1      True  ...   True   True  False  False   True  False   True  False
# 2     False  ...  False  False  False  False  False  False  False  False
# 3     False  ...  False  False  False  False  False  False  False  False
# 4      True  ...   True   True  False  False   True  False   True  False
# ...     ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 7121  False  ...  False  False  False  False  False  False  False  False
# 7122  False  ...  False  False  False  False  False  False  False  False
# 7123  False  ...  False  False  False  False  False  False  False  False
# 7124  False  ...  False  False  False  False  False  False  False  False
# 7125  False  ...  False  False  False  False  False  False  False  False
#
#         100  Ntrue
# 0     False     15
# 1      True     53
# 2     False      0
# 3     False      0
# 4      True     53
# ...     ...    ...
# 7121  False      0
# 7122  False      0
# 7123  False      0
# 7124  False      0
# 7125  False      0
#
# [7126 rows x 102 columns]
#      locus_name      1      2      3      4      5      6      7      8  \
# 0      15S_rRNA  False   True  False  False  False  False  False  False
# 1      21S_rRNA  False   True  False  False  False  False  False  False
# 2          HRA1  False  False  False  False  False  False  False  False
# 3          ICR1  False  False  False  False  False  False  False  False
# 4          LSR1  False  False  False  False  False  False  False  False
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 7121  tY(GUA)J2  False  False  False  False  False  False  False  False
# 7122  tY(GUA)M1  False  False  False  False  False  False  False  False
# 7123  tY(GUA)M2  False  False  False  False  False  False  False  False
# 7124   tY(GUA)O  False  False  False  False  False  False  False  False
# 7125   tY(GUA)Q  False  False  False  False  False  False  False  False
#
#           9  ...     92     93     94     95     96     97     98     99  \
# 0     False  ...  False   True  False  False  False  False  False  False
# 1     False  ...  False   True  False  False  False  False  False  False
# 2     False  ...  False  False  False  False  False  False  False  False
# 3     False  ...  False  False  False  False  False  False  False  False
# 4     False  ...  False  False  False  False  False  False  False  False
# ...     ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 7121  False  ...  False  False  False  False  False  False  False  False
# 7122  False  ...  False  False  False  False  False  False  False  False
# 7123  False  ...  False  False  False  False  False  False  False  False
# 7124  False  ...  False  False  False  False  False  False  False  False
# 7125  False  ...  False  False  False  False  False  False  False  False
#
#         100  Ntrue
# 0     False     15
# 1     False     10
# 2     False      0
# 3     False      0
# 4     False      1
# ...     ...    ...
# 7121  False      0
# 7122  False      0
# 7123  False      0
# 7124  False      0
# 7125  False      0
#
# [7126 rows x 102 columns]
#      locus_name      1      2      3      4      5      6      7      8  \
# 0      15S_rRNA  False  False  False  False  False  False  False  False
# 1      21S_rRNA  False  False  False  False  False  False  False  False
# 2          HRA1  False  False  False  False  False  False  False  False
# 3          ICR1  False  False  False  False  False  False  False  False
# 4          LSR1  False  False  False  False  False  False  False  False
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 7121  tY(GUA)J2  False  False  False  False  False  False  False  False
# 7122  tY(GUA)M1  False  False  False  False  False  False  False  False
# 7123  tY(GUA)M2  False  False  False  False  False  False  False  False
# 7124   tY(GUA)O  False  False  False  False  False  False  False  False
# 7125   tY(GUA)Q  False  False  False  False  False  False  False  False
#
#           9  ...     92     93     94     95     96     97     98     99  \
# 0     False  ...  False  False  False  False  False  False  False  False
# 1     False  ...  False  False  False  False  False  False  False  False
# 2     False  ...  False  False  False  False  False  False  False  False
# 3     False  ...  False  False  False  False  False  False  False  False
# 4     False  ...  False  False  False  False  False  False  False  False
# ...     ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 7121  False  ...  False  False  False  False  False  False  False  False
# 7122  False  ...  False  False  False  False  False  False  False  False
# 7123  False  ...  False  False  False  False  False  False  False  False
# 7124  False  ...  False  False  False  False  False  False  False  False
# 7125  False  ...  False  False  False  False  False  False  False  False
#
#         100  Ntrue
# 0     False      0
# 1     False      0
# 2     False      0
# 3     False      0
# 4     False      0
# ...     ...    ...
# 7121  False      0
# 7122  False      0
# 7123  False      0
# 7124  False      0
# 7125  False      0
#
# [7126 rows x 102 columns]

# %%
fig, axs = plt.subplots(1, 1, sharey=True, figsize=(6, 4), dpi=300)

# scatters
axs.scatter(np.arange(1, 101),
            CONTROL_R10_bayexpress_FC0.iloc[:, 1:-1].sum(axis=0),
            c='#332288', s=30,
            label=f'BF > 1, FC > 0, total = {sum(CONTROL_R10_bayexpress_FC0.iloc[:,1:-1].sum(axis=0))}',
            alpha=0.9, marker='x')

axs.scatter(np.arange(1, 101),
            CONTROL_R10_bayexpress_FC1.iloc[:, 1:-1].sum(axis=0),
            c='#44AA99', s=30,
            label=f'BF > 1, FC > 1, total = {sum(CONTROL_R10_bayexpress_FC1.iloc[:,1:-1].sum(axis=0))}',
            alpha=0.9, marker='x')

axs.scatter(np.arange(1, 101),
            CONTROL_R10_bayexpress_FC2.iloc[:, 1:-1].sum(axis=0),
            c='#CC6677', s=30,
            label=f'BF > 1, FC > 2, total = {sum(CONTROL_R10_bayexpress_FC2.iloc[:,1:-1].sum(axis=0))}',
            alpha=0.9, marker='x')

axs.legend(loc='upper left')

# Use tex in labels
axs.set_xticks(np.arange(1, 101))
axs.set_xticklabels('')

# formatting y axis ticks
plt.gca().ticklabel_format(axis='y', style='plain', useOffset=False)

axs.set_xlabel('100 Bootstrapping iterations')
axs.set_ylabel('# putative differentially expressed genes')

# Set y limit 3500
axs.set_ylim(-100, 3500)

plt.show()

# %%
# zoom in

fig, axs = plt.subplots(1, 1, sharey=True, figsize=(6, 4), dpi=300)

# scatters
axs.scatter(np.arange(1, 101),
            CONTROL_R10_bayexpress_FC0.iloc[:, 1:-1].sum(axis=0),
            c='#332288', s=30,
            label=f'BF > 1, FC > 0, total = {sum(CONTROL_R10_bayexpress_FC0.iloc[:,1:-1].sum(axis=0))}',
            alpha=0.9, marker='x')

axs.scatter(np.arange(1, 101),
            CONTROL_R10_bayexpress_FC1.iloc[:, 1:-1].sum(axis=0),
            c='#44AA99', s=30,
            label=f'BF > 1, FC > 1, total = {sum(CONTROL_R10_bayexpress_FC1.iloc[:,1:-1].sum(axis=0))}',
            alpha=0.9, marker='x')

axs.scatter(np.arange(1, 101),
            CONTROL_R10_bayexpress_FC2.iloc[:, 1:-1].sum(axis=0),
            c='#CC6677', s=30,
            label=f'BF > 1, FC > 2, total = {sum(CONTROL_R10_bayexpress_FC2.iloc[:,1:-1].sum(axis=0))}',
            alpha=0.9, marker='x')

axs.legend(loc='upper left')

# Use tex in labels
axs.set_xticks(np.arange(1, 101))
axs.set_xticklabels('')

# formatting y axis ticks
plt.gca().ticklabel_format(axis='y', style='plain', useOffset=False)

axs.set_xlabel('100 Bootstrapping iterations')
axs.set_ylabel('# putative differentially expressed genes')

# Set y limit to 300
axs.set_ylim(-10, 300)

plt.show()

# %%
# just a different visualisation

fig, axs = plt.subplots(1,1,sharey=True, figsize=(6,4), dpi=300)


series = CONTROL_R10_bayexpress_FC0.iloc[:,1:-1].sum(axis=0)
series.plot(kind='line', color='#332288', alpha=0.8, ylim=[-5,500], linewidth=2, label=f'BF > 1, FC > 0, total = {sum(CONTROL_R10_bayexpress_FC0.iloc[:,1:-1].sum(axis=0))}')

series = CONTROL_R10_bayexpress_FC1.iloc[:,1:-1].sum(axis=0)
series.plot(kind='line', color='#44AA99', alpha=0.8, ylim=[-5,500], linewidth=2, label=f'BF > 1, FC > 1, total = {sum(CONTROL_R10_bayexpress_FC1.iloc[:,1:-1].sum(axis=0))}')

series = CONTROL_R10_bayexpress_FC2.iloc[:,1:-1].sum(axis=0)
series.plot(kind='line', color='#CC6677', alpha=0.8, ylim=[-5,500], linewidth=2, label=f'BF > 1, FC > 2, total = {sum(CONTROL_R10_bayexpress_FC2.iloc[:,1:-1].sum(axis=0))}')

axs.set_xlabel('Bootstrapping iterations')
axs.set_ylabel('# putative differentially expressed genes')

axs.legend(loc='center left')
axs.set_xticks([1,100])
axs.set_xticklabels(['1', '100'])


plt.show()

# %%
# R10 means number of replicates in 100 bootstrapping iterations is 10
# FC > 0
# got hits (any)

# let's find out which genes we found to produce hits in the control and see if we can identify them with Bayes factors for consistency

print('Find genes that got hits in the control experiment')
display(CONTROL_R10_bayexpress_FC0.loc[CONTROL_R10_bayexpress_FC0.Ntrue > 0])

# importing results from differential gene expression anaylsis to check what they are
RALL_bayexpress = pd.read_csv('RALL_bayexpress.csv', index_col=0)

print('All replicates, bayexpress results')
display(RALL_bayexpress)

print('Display only the genes that got hits in the control experiment')
display(RALL_bayexpress.iloc[(CONTROL_R10_bayexpress_FC0.loc[CONTROL_R10_bayexpress_FC0.Ntrue > 0].index)])

print('Display only the genes that got hits in the control experiment + where identified with bayes factors for consistency of replicates in the WT')
display(RALL_bayexpress.iloc[(CONTROL_R10_bayexpress_FC0.loc[CONTROL_R10_bayexpress_FC0.Ntrue > 0].index)].loc[(RALL_bayexpress.nBF_WT > 1)])

print('Display only the genes that got hits in the control experiment + where NOT identified with bayes factors for consistency of replicates in the WT')
display(RALL_bayexpress.iloc[(CONTROL_R10_bayexpress_FC0.loc[CONTROL_R10_bayexpress_FC0.Ntrue > 0].index)].loc[(RALL_bayexpress.nBF_WT < 1)])

print('Among the genes that produced 0 hits, where there any genes that would be identified as variable by nBF > 1?')
display(RALL_bayexpress.iloc[(CONTROL_R10_bayexpress_FC0.loc[CONTROL_R10_bayexpress_FC0.Ntrue == 0].index)].loc[(RALL_bayexpress.nBF_WT > 1)])
# Out:
# Find genes that got hits in the control experiment
#      locus_name      1      2      3      4      5      6      7      8  \
# 0      15S_rRNA  False   True  False  False  False  False  False  False
# 1      21S_rRNA  False   True  False   True   True  False   True  False
# 4          LSR1  False   True  False  False  False  False  False  False
# 5          NME1  False  False  False  False  False  False  False  False
# 11        Q0050  False  False  False  False  False  False  False  False
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6817       snR8   True  False  False  False  False  False  False  False
# 6820      snR82  False  False  False  False  False  False  False  False
# 6821      snR83  False   True  False  False   True   True  False  False
# 6822      snR84  False  False  False  False  False  False  False  False
# 6824      snR86  False   True  False  False   True   True   True   True
#
#           9  ...     92     93     94     95     96     97     98     99  \
# 0     False  ...  False   True  False  False  False  False  False  False
# 1      True  ...   True   True  False  False   True  False   True  False
# 4      True  ...   True   True  False  False   True  False   True  False
# 5     False  ...  False  False  False  False  False  False  False  False
# 11    False  ...  False  False  False  False  False  False  False  False
# ...     ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6817  False  ...  False  False  False  False  False  False  False  False
# 6820  False  ...  False  False  False  False  False  False  False  False
# 6821  False  ...  False  False  False  False  False  False   True   True
# 6822  False  ...  False  False  False  False  False  False  False  False
# 6824   True  ...  False  False  False  False  False  False   True  False
#
#         100  Ntrue
# 0     False     15
# 1      True     53
# 4      True     53
# 5     False      1
# 11    False      2
# ...     ...    ...
# 6817  False      2
# 6820  False      3
# 6821  False     20
# 6822  False      4
# 6824  False     38
#
# [4867 rows x 102 columns]
# All replicates, bayexpress results
#      locus_name         BF        FC      nBF_WT  AOTP_WT     nBF_Snf2  \
# 0      15S_rRNA  -3.710645  0.274047 -107.138056    False    53.627445
# 1      21S_rRNA  -1.302642  0.147177  362.115507     True  1052.203968
# 2          HRA1  -5.206545 -0.564787 -240.338654    False  -258.581365
# 3          ICR1  76.746125  0.504048 -194.077441    False  -196.467262
# 4          LSR1   0.451012  0.120243  251.787125     True   478.066414
# ...         ...        ...       ...         ...      ...          ...
# 7121  tY(GUA)J2  -7.312143  0.861839 -270.299503    False  -281.214963
# 7122  tY(GUA)M1  -7.406574  0.022303 -262.736078    False  -275.253246
# 7123  tY(GUA)M2  -7.727890  0.183767 -271.177492    False  -284.863866
# 7124   tY(GUA)O  -7.622253  0.347266 -270.291196    False  -282.682788
# 7125   tY(GUA)Q  -8.273720 -0.138161 -275.349735    False  -289.991744
#
#       AOTP_Snf2
# 0          True
# 1          True
# 2         False
# 3         False
# 4          True
# ...         ...
# 7121      False
# 7122      False
# 7123      False
# 7124      False
# 7125      False
#
# [7126 rows x 7 columns]
# Display only the genes that got hits in the control experiment
#      locus_name          BF        FC      nBF_WT  AOTP_WT     nBF_Snf2  \
# 0      15S_rRNA   -3.710645  0.274047 -107.138056    False    53.627445
# 1      21S_rRNA   -1.302642  0.147177  362.115507     True  1052.203968
# 4          LSR1    0.451012  0.120243  251.787125     True   478.066414
# 5          NME1   -0.117540  0.325530 -194.522309    False  -176.114481
# 11        Q0050   -3.832185  0.372953 -190.887348    False  -114.388704
# ...         ...         ...       ...         ...      ...          ...
# 6817       snR8   -4.021802 -0.105108 -163.004723    False  -158.261430
# 6820      snR82  153.959142  0.821886 -170.445138    False  -172.395022
# 6821      snR83   -5.961317 -0.049198  -97.702962    False  -164.859374
# 6822      snR84   14.487733  0.289726 -169.091308    False  -187.905653
# 6824      snR86  272.275536  0.372995  120.984196     True   160.053022
#
#       AOTP_Snf2
# 0          True
# 1          True
# 4          True
# 5         False
# 11        False
# ...         ...
# 6817      False
# 6820      False
# 6821      False
# 6822      False
# 6824       True
#
# [4867 rows x 7 columns]
# Display only the genes that got hits in the control experiment + where identified with bayes factors for consistency of replicates in the WT
#      locus_name          BF        FC      nBF_WT  AOTP_WT     nBF_Snf2  \
# 1      21S_rRNA   -1.302642  0.147177  362.115507     True  1052.203968
# 4          LSR1    0.451012  0.120243  251.787125     True   478.066414
# 41       RDN5-1   13.774601  0.316040  246.914584     True   521.186933
# 46       RDN5-6   15.230943  0.469612  172.850686     True   347.304031
# 56       RUF5-1   -1.191579  0.080133  232.720615     True     4.230186
# ...         ...         ...       ...         ...      ...          ...
# 6730    YPR190C   48.045047 -0.216275  135.716958     True  -136.905959
# 6731    YPR191W  218.989419  0.279871  251.986788     True   -38.705868
# 6752     snR17a    7.383833  0.329308   28.421292     True   239.879652
# 6761      snR30   20.556922  0.159709    2.616569     True    85.355966
# 6824      snR86  272.275536  0.372995  120.984196     True   160.053022
#
#       AOTP_Snf2
# 1          True
# 4          True
# 41         True
# 46         True
# 56         True
# ...         ...
# 6730      False
# 6731      False
# 6752       True
# 6761       True
# 6824       True
#
# [1602 rows x 7 columns]
# Display only the genes that got hits in the control experiment + where NOT identified with bayes factors for consistency of replicates in the WT
#      locus_name          BF        FC      nBF_WT  AOTP_WT    nBF_Snf2  \
# 0      15S_rRNA   -3.710645  0.274047 -107.138056    False   53.627445
# 5          NME1   -0.117540  0.325530 -194.522309    False -176.114481
# 11        Q0050   -3.832185  0.372953 -190.887348    False -114.388704
# 12        Q0055   -1.269154  0.623327 -202.214537    False -142.662683
# 51         RPR1  102.505781 -0.973507  -29.530821    False -163.636890
# ...         ...         ...       ...         ...      ...         ...
# 6813      snR76   -5.708708  0.112789 -200.195124    False -225.684507
# 6817       snR8   -4.021802 -0.105108 -163.004723    False -158.261430
# 6820      snR82  153.959142  0.821886 -170.445138    False -172.395022
# 6821      snR83   -5.961317 -0.049198  -97.702962    False -164.859374
# 6822      snR84   14.487733  0.289726 -169.091308    False -187.905653
#
#       AOTP_Snf2
# 0          True
# 5         False
# 11        False
# 12        False
# 51        False
# ...         ...
# 6813      False
# 6817      False
# 6820      False
# 6821      False
# 6822      False
#
# [3265 rows x 7 columns]
# Among the genes that produced 0 hits, where there any genes that would be identified as variable by nBF > 1?
# Empty DataFrame
# Columns: [locus_name, BF, FC, nBF_WT, AOTP_WT, nBF_Snf2, AOTP_Snf2]
# Index: []

# %%
# R10 means number of replicates in 100 bootstrapping iterations is 10
# FC > 0
# got more than 10 hits

# let's find out which genes we found to produce hits in the control and see if we can identify them with Bayes factors for consistency

print('Find genes that got more than 10 hits in the control experiment')
display(CONTROL_R10_bayexpress_FC0.loc[CONTROL_R10_bayexpress_FC0.Ntrue > 10])

# importing results from differential gene expression anaylsis to check what they are
RALL_bayexpress = pd.read_csv('RALL_bayexpress.csv', index_col=0)

print('All replicates, bayexpress results')
display(RALL_bayexpress)

print('Display only the genes that got more than 10 hits in the control experiment')
display(RALL_bayexpress.iloc[(CONTROL_R10_bayexpress_FC0.loc[CONTROL_R10_bayexpress_FC0.Ntrue > 10].index)])

print('Display only the genes that got more than 10 hits in the control experiment + where identified with bayes factors for consistency of replicates in the WT')
display(RALL_bayexpress.iloc[(CONTROL_R10_bayexpress_FC0.loc[CONTROL_R10_bayexpress_FC0.Ntrue > 10].index)].loc[(RALL_bayexpress.nBF_WT > 1)])

print('Display only the genes that got more than 10 hits in the control experiment + where NOT identified with bayes factors for consistency of replicates in the WT')
display(RALL_bayexpress.iloc[(CONTROL_R10_bayexpress_FC0.loc[CONTROL_R10_bayexpress_FC0.Ntrue > 10].index)].loc[(RALL_bayexpress.nBF_WT < 1)])
# Out:
# Find genes that got more than 10 hits in the control experiment
#      locus_name      1      2      3      4      5      6      7      8  \
# 0      15S_rRNA  False   True  False  False  False  False  False  False
# 1      21S_rRNA  False   True  False   True   True  False   True  False
# 4          LSR1  False   True  False  False  False  False  False  False
# 41       RDN5-1  False   True  False  False   True   True  False  False
# 46       RDN5-6   True   True  False  False   True   True  False  False
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6768      snR37  False   True  False  False  False  False  False  False
# 6777      snR44  False  False  False  False   True   True  False  False
# 6782      snR49  False  False  False  False  False   True  False  False
# 6821      snR83  False   True  False  False   True   True  False  False
# 6824      snR86  False   True  False  False   True   True   True   True
#
#           9  ...     92     93     94     95     96     97     98     99  \
# 0     False  ...  False   True  False  False  False  False  False  False
# 1      True  ...   True   True  False  False   True  False   True  False
# 4      True  ...   True   True  False  False   True  False   True  False
# 41     True  ...  False   True  False  False  False  False  False  False
# 46     True  ...  False   True  False  False  False  False  False  False
# ...     ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6768   True  ...   True   True  False  False  False  False   True  False
# 6777   True  ...  False  False  False  False   True  False   True  False
# 6782  False  ...  False  False  False  False  False  False   True  False
# 6821  False  ...  False  False  False  False  False  False   True   True
# 6824   True  ...  False  False  False  False  False  False   True  False
#
#         100  Ntrue
# 0     False     15
# 1      True     53
# 4      True     53
# 41     True     43
# 46     True     48
# ...     ...    ...
# 6768   True     25
# 6777  False     23
# 6782  False     14
# 6821  False     20
# 6824  False     38
#
# [3146 rows x 102 columns]
# All replicates, bayexpress results
#      locus_name         BF        FC      nBF_WT  AOTP_WT     nBF_Snf2  \
# 0      15S_rRNA  -3.710645  0.274047 -107.138056    False    53.627445
# 1      21S_rRNA  -1.302642  0.147177  362.115507     True  1052.203968
# 2          HRA1  -5.206545 -0.564787 -240.338654    False  -258.581365
# 3          ICR1  76.746125  0.504048 -194.077441    False  -196.467262
# 4          LSR1   0.451012  0.120243  251.787125     True   478.066414
# ...         ...        ...       ...         ...      ...          ...
# 7121  tY(GUA)J2  -7.312143  0.861839 -270.299503    False  -281.214963
# 7122  tY(GUA)M1  -7.406574  0.022303 -262.736078    False  -275.253246
# 7123  tY(GUA)M2  -7.727890  0.183767 -271.177492    False  -284.863866
# 7124   tY(GUA)O  -7.622253  0.347266 -270.291196    False  -282.682788
# 7125   tY(GUA)Q  -8.273720 -0.138161 -275.349735    False  -289.991744
#
#       AOTP_Snf2
# 0          True
# 1          True
# 2         False
# 3         False
# 4          True
# ...         ...
# 7121      False
# 7122      False
# 7123      False
# 7124      False
# 7125      False
#
# [7126 rows x 7 columns]
# Display only the genes that got more than 10 hits in the control experiment
#      locus_name          BF        FC      nBF_WT  AOTP_WT     nBF_Snf2  \
# 0      15S_rRNA   -3.710645  0.274047 -107.138056    False    53.627445
# 1      21S_rRNA   -1.302642  0.147177  362.115507     True  1052.203968
# 4          LSR1    0.451012  0.120243  251.787125     True   478.066414
# 41       RDN5-1   13.774601  0.316040  246.914584     True   521.186933
# 46       RDN5-6   15.230943  0.469612  172.850686     True   347.304031
# ...         ...         ...       ...         ...      ...          ...
# 6768      snR37    2.932227 -0.229684  -57.966295    False   -50.162245
# 6777      snR44   44.784503 -0.377448  -69.135666    False  -160.634165
# 6782      snR49    3.810074 -0.194770 -128.891351    False  -181.780529
# 6821      snR83   -5.961317 -0.049198  -97.702962    False  -164.859374
# 6824      snR86  272.275536  0.372995  120.984196     True   160.053022
#
#       AOTP_Snf2
# 0          True
# 1          True
# 4          True
# 41         True
# 46         True
# ...         ...
# 6768      False
# 6777      False
# 6782      False
# 6821      False
# 6824       True
#
# [3146 rows x 7 columns]
# Display only the genes that got more than 10 hits in the control experiment + where identified with bayes factors for consistency of replicates in the WT
#      locus_name          BF        FC      nBF_WT  AOTP_WT     nBF_Snf2  \
# 1      21S_rRNA   -1.302642  0.147177  362.115507     True  1052.203968
# 4          LSR1    0.451012  0.120243  251.787125     True   478.066414
# 41       RDN5-1   13.774601  0.316040  246.914584     True   521.186933
# 46       RDN5-6   15.230943  0.469612  172.850686     True   347.304031
# 56       RUF5-1   -1.191579  0.080133  232.720615     True     4.230186
# ...         ...         ...       ...         ...      ...          ...
# 6730    YPR190C   48.045047 -0.216275  135.716958     True  -136.905959
# 6731    YPR191W  218.989419  0.279871  251.986788     True   -38.705868
# 6752     snR17a    7.383833  0.329308   28.421292     True   239.879652
# 6761      snR30   20.556922  0.159709    2.616569     True    85.355966
# 6824      snR86  272.275536  0.372995  120.984196     True   160.053022
#
#       AOTP_Snf2
# 1          True
# 4          True
# 41         True
# 46         True
# 56         True
# ...         ...
# 6730      False
# 6731      False
# 6752       True
# 6761       True
# 6824       True
#
# [1602 rows x 7 columns]
# Display only the genes that got more than 10 hits in the control experiment + where NOT identified with bayes factors for consistency of replicates in the WT
#      locus_name          BF        FC      nBF_WT  AOTP_WT    nBF_Snf2  \
# 0      15S_rRNA   -3.710645  0.274047 -107.138056    False   53.627445
# 51         RPR1  102.505781 -0.973507  -29.530821    False -163.636890
# 52        RUF20   58.301953  0.467352  -87.667016    False -105.505837
# 53        RUF21   24.026871  0.572910  -40.011620    False  -18.211398
# 61      YAL001C  510.650373  0.634130  -70.980470    False  -69.042919
# ...         ...         ...       ...         ...      ...         ...
# 6764      snR33  199.657711  0.726279 -127.595505    False -111.255116
# 6768      snR37    2.932227 -0.229684  -57.966295    False  -50.162245
# 6777      snR44   44.784503 -0.377448  -69.135666    False -160.634165
# 6782      snR49    3.810074 -0.194770 -128.891351    False -181.780529
# 6821      snR83   -5.961317 -0.049198  -97.702962    False -164.859374
#
#       AOTP_Snf2
# 0          True
# 51        False
# 52        False
# 53        False
# 61        False
# ...         ...
# 6764      False
# 6768      False
# 6777      False
# 6782      False
# 6821      False
#
# [1544 rows x 7 columns]

# %%
# R10 means number of replicates in 100 bootstrapping iterations is 10
# FC > 1
# got hits (any)

# let's find out which genes we found to produce hits in the control and see if we can identify them with Bayes factors for consistency

print('Find genes that got hits in the control experiment')
display(CONTROL_R10_bayexpress_FC1.loc[CONTROL_R10_bayexpress_FC1.Ntrue > 0])

# importing results from differential gene expression anaylsis to check what they are
RALL_bayexpress = pd.read_csv('RALL_bayexpress.csv', index_col=0)

print('All replicates, bayexpress results')
display(RALL_bayexpress)

print('Display only the genes that got hits in the control experiment')
display(RALL_bayexpress.iloc[(CONTROL_R10_bayexpress_FC1.loc[CONTROL_R10_bayexpress_FC1.Ntrue > 0].index)])

print('Display only the genes that got hits in the control experiment + where identified with bayes factors for consistency of replicates in the WT')
display(RALL_bayexpress.iloc[(CONTROL_R10_bayexpress_FC1.loc[CONTROL_R10_bayexpress_FC1.Ntrue > 0].index)].loc[(RALL_bayexpress.nBF_WT > 1)])

print('Display only the genes that got hits in the control experiment + where NOT identified with bayes factors for consistency of replicates in the WT')
display(RALL_bayexpress.iloc[(CONTROL_R10_bayexpress_FC1.loc[CONTROL_R10_bayexpress_FC1.Ntrue > 0].index)].loc[(RALL_bayexpress.nBF_WT < 1)])

print('Among the genes that produced 0 hits, where there any genes that would be identified as variable by nBF > 1?')
display(RALL_bayexpress.iloc[(CONTROL_R10_bayexpress_FC1.loc[CONTROL_R10_bayexpress_FC1.Ntrue == 0].index)].loc[(RALL_bayexpress.nBF_WT > 1)])
# Out:
# Find genes that got hits in the control experiment
#      locus_name      1      2      3      4      5      6      7      8  \
# 0      15S_rRNA  False   True  False  False  False  False  False  False
# 1      21S_rRNA  False   True  False  False  False  False  False  False
# 4          LSR1  False  False  False  False  False  False  False  False
# 11        Q0050  False  False  False  False  False  False  False  False
# 12        Q0055  False  False  False  False  False  False  False  False
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6757     snR190  False   True  False  False  False   True  False  False
# 6785      snR51  False  False  False  False  False   True  False  False
# 6789      snR55  False  False  False  False  False  False  False  False
# 6803      snR68  False  False  False  False  False   True  False  False
# 6821      snR83  False  False  False  False  False  False  False  False
#
#           9  ...     92     93     94     95     96     97     98     99  \
# 0     False  ...  False   True  False  False  False  False  False  False
# 1     False  ...  False   True  False  False  False  False  False  False
# 4     False  ...  False  False  False  False  False  False  False  False
# 11    False  ...  False  False  False  False  False  False  False  False
# 12    False  ...  False  False  False  False  False  False  False  False
# ...     ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6757   True  ...  False   True  False  False  False  False   True  False
# 6785  False  ...  False  False  False  False  False  False  False  False
# 6789  False  ...  False  False  False  False  False  False   True  False
# 6803  False  ...  False  False  False  False  False  False   True  False
# 6821  False  ...  False  False  False  False  False  False  False  False
#
#         100  Ntrue
# 0     False     15
# 1     False     10
# 4     False      1
# 11    False      2
# 12    False      1
# ...     ...    ...
# 6757   True     28
# 6785  False      1
# 6789  False      2
# 6803  False      3
# 6821  False      1
#
# [68 rows x 102 columns]
# All replicates, bayexpress results
#      locus_name         BF        FC      nBF_WT  AOTP_WT     nBF_Snf2  \
# 0      15S_rRNA  -3.710645  0.274047 -107.138056    False    53.627445
# 1      21S_rRNA  -1.302642  0.147177  362.115507     True  1052.203968
# 2          HRA1  -5.206545 -0.564787 -240.338654    False  -258.581365
# 3          ICR1  76.746125  0.504048 -194.077441    False  -196.467262
# 4          LSR1   0.451012  0.120243  251.787125     True   478.066414
# ...         ...        ...       ...         ...      ...          ...
# 7121  tY(GUA)J2  -7.312143  0.861839 -270.299503    False  -281.214963
# 7122  tY(GUA)M1  -7.406574  0.022303 -262.736078    False  -275.253246
# 7123  tY(GUA)M2  -7.727890  0.183767 -271.177492    False  -284.863866
# 7124   tY(GUA)O  -7.622253  0.347266 -270.291196    False  -282.682788
# 7125   tY(GUA)Q  -8.273720 -0.138161 -275.349735    False  -289.991744
#
#       AOTP_Snf2
# 0          True
# 1          True
# 2         False
# 3         False
# 4          True
# ...         ...
# 7121      False
# 7122      False
# 7123      False
# 7124      False
# 7125      False
#
# [7126 rows x 7 columns]
# Display only the genes that got hits in the control experiment
#      locus_name        BF        FC      nBF_WT  AOTP_WT     nBF_Snf2  \
# 0      15S_rRNA -3.710645  0.274047 -107.138056    False    53.627445
# 1      21S_rRNA -1.302642  0.147177  362.115507     True  1052.203968
# 4          LSR1  0.451012  0.120243  251.787125     True   478.066414
# 11        Q0050 -3.832185  0.372953 -190.887348    False  -114.388704
# 12        Q0055 -1.269154  0.623327 -202.214537    False  -142.662683
# ...         ...       ...       ...         ...      ...          ...
# 6757     snR190 -6.562044 -0.001634  -49.290008    False   -63.762229
# 6785      snR51  8.669724  0.499160 -183.979922    False  -187.503838
# 6789      snR55 -0.427158  0.526784 -216.042758    False  -223.288469
# 6803      snR68 -6.423593  0.080598 -196.623851    False  -228.564192
# 6821      snR83 -5.961317 -0.049198  -97.702962    False  -164.859374
#
#       AOTP_Snf2
# 0          True
# 1          True
# 4          True
# 11        False
# 12        False
# ...         ...
# 6757      False
# 6785      False
# 6789      False
# 6803      False
# 6821      False
#
# [68 rows x 7 columns]
# Display only the genes that got hits in the control experiment + where identified with bayes factors for consistency of replicates in the WT
#      locus_name            BF        FC        nBF_WT  AOTP_WT     nBF_Snf2  \
# 1      21S_rRNA     -1.302642  0.147177    362.115507     True  1052.203968
# 4          LSR1      0.451012  0.120243    251.787125     True   478.066414
# 41       RDN5-1     13.774601  0.316040    246.914584     True   521.186933
# 46       RDN5-6     15.230943  0.469612    172.850686     True   347.304031
# 58         SCR1     10.530223  0.125605   3463.535578     True  5939.249536
# 104   YAL037C-B     -0.026307 -0.114575    402.523899     True   305.562530
# 740     YCR021C   6285.979055 -2.312448   3075.033017     True  -200.094307
# 1236    YDR133C    633.970158 -0.796620   1321.491205     True   364.619590
# 1661  YDR524W-C   2433.134417  0.599017   6596.560889     True  7411.509121
# 1725    YEL033W     23.839270 -0.219443    530.392958     True   191.684677
# 1893    YER091C  16720.982384  1.209366  11172.902928     True   208.046987
# 2125    YFR032C     -2.313784 -0.167096     10.849885     True  -174.178322
# 2149  YFR052C-A    518.610442 -0.985185    945.154728     True    54.584141
# 2345    YGL184C     19.779086  0.267701   1232.526242     True  -187.281082
# 2581    YGR142W     -2.131331  0.076279    473.880712     True   -51.428615
# 4049    YKR080W  11373.906779 -2.199797   5857.539836     True   -79.673667
# 4226    YLR076C     52.271901  0.295462    447.226573     True   230.348063
# 4330    YLR162W    119.338212 -0.268336   5959.704092     True  5323.348914
# 4331  YLR162W-A     -2.223327 -0.059773   2858.237808     True  3645.853301
# 4525  YLR342W-A     99.672642  0.714200     53.416615     True   194.250092
# 5496    YNL303W     -5.296007  0.079900    102.367316     True   -47.590184
# 6127    YOR309C     -5.763854 -0.040480    124.276754     True    -4.400978
# 6569    YPR044C     -5.552581  0.073819     67.995942     True   -30.565124
# 6752     snR17a      7.383833  0.329308     28.421292     True   239.879652
#
#       AOTP_Snf2
# 1          True
# 4          True
# 41         True
# 46         True
# 58         True
# 104        True
# 740       False
# 1236       True
# 1661       True
# 1725       True
# 1893       True
# 2125      False
# 2149       True
# 2345      False
# 2581      False
# 4049      False
# 4226       True
# 4330       True
# 4331       True
# 4525       True
# 5496      False
# 6127      False
# 6569      False
# 6752       True
# Display only the genes that got hits in the control experiment + where NOT identified with bayes factors for consistency of replicates in the WT
#      locus_name         BF        FC      nBF_WT  AOTP_WT    nBF_Snf2  \
# 0      15S_rRNA  -3.710645  0.274047 -107.138056    False   53.627445
# 11        Q0050  -3.832185  0.372953 -190.887348    False -114.388704
# 12        Q0055  -1.269154  0.623327 -202.214537    False -142.662683
# 53        RUF21  24.026871  0.572910  -40.011620    False  -18.211398
# 89    YAL026C-A  34.843922  0.889168 -177.688653    False -174.081566
# 103   YAL037C-A   1.234011 -0.338439  -16.174943    False -127.606812
# 269     YBL077W   8.840953  0.374675 -138.677913    False -165.974434
# 371   YBR056W-A  -0.551801 -0.477699 -199.258799    False -232.583341
# 519     YBR190W  -6.162852  0.068453 -127.176368    False -127.193474
# 521   YBR191W-A  -2.073965  0.242930  -41.687820    False  -37.177753
# 702     YCL058C  40.001959  0.821113 -156.071877    False -143.479336
# 929     YDL094C  21.928193  0.725553 -196.460134    False -185.558100
# 996     YDL158C  63.381742  0.722901 -134.671667    False -110.514422
# 1026  YDL185C-A  17.676173 -0.867276 -192.785275    False -226.363875
# 1070    YDL228C  -6.080882 -0.076954  -97.659005    False -132.975270
# 1118    YDR024W  -6.454728 -0.058904 -184.426775    False -194.117426
# 1290  YDR183C-A  11.146833 -0.700943 -142.305452    False -207.136546
# 1538  YDR406W-A  -1.338486 -0.434386 -163.390623    False -218.090466
# 1565    YDR433W   0.766362  0.403795 -194.934443    False -201.131596
# 1637    YDR504C  73.845677  0.858922 -105.658685    False -111.919707
# 1657    YDR523C  12.770130 -0.403779  -50.576683    False -223.229099
# 1960  YER148W-A  -6.570242  0.224409 -231.094041    False -240.931362
# 2331    YGL170C   0.416229 -0.455614 -173.101232    False -236.475004
# 2453    YGR025W  -0.381789  0.266660 -130.960566    False -157.582010
# 3110  YIL030W-A  26.024480  0.992939 -202.849593    False -195.704196
# 3416    YJL089W  -6.163922  0.114138 -188.852713    False -235.752566
# 3648    YJR087W   0.225967  0.473881 -203.658978    False -228.252534
# 3811    YKL076C  26.486063  0.713113 -190.873191    False -194.480655
# 3862    YKL123W  18.289525  0.952339 -208.128196    False -210.354898
# 4099    YLL020C  67.992742  1.187350 -194.452322    False -201.872057
# 4212    YLR062C  -5.711755 -0.087536  -82.288570    False -140.545094
# 4314  YLR154W-E  -3.151336 -0.176792  -60.248108    False -149.662561
# 4315  YLR154W-F   5.995940  0.364397  -92.559879    False -177.842838
# 5980    YOR169C  -6.487829 -0.051168 -139.559004    False -175.662102
# 5981    YOR170W  28.454606  0.766547 -179.329102    False -190.131648
# 6040    YOR225W  49.852650  0.916290 -196.028539    False -199.887966
# 6346  YPL119C-A  71.011627  0.931191 -167.191005    False -143.258720
# 6357    YPL130W   7.958170  0.425944  -94.156259    False -173.879273
# 6370    YPL142C  -5.468159  0.088311  -42.710655    False  -95.295908
# 6757     snR190  -6.562044 -0.001634  -49.290008    False  -63.762229
# 6785      snR51   8.669724  0.499160 -183.979922    False -187.503838
# 6789      snR55  -0.427158  0.526784 -216.042758    False -223.288469
# 6803      snR68  -6.423593  0.080598 -196.623851    False -228.564192
# 6821      snR83  -5.961317 -0.049198  -97.702962    False -164.859374
#
#       AOTP_Snf2
# 0          True
# 11        False
# 12        False
# 53        False
# 89        False
# 103       False
# 269       False
# 371       False
# 519       False
# 521       False
# 702       False
# 929       False
# 996       False
# 1026      False
# 1070      False
# 1118      False
# 1290      False
# 1538      False
# 1565      False
# 1637      False
# 1657      False
# 1960      False
# 2331      False
# 2453      False
# 3110      False
# 3416      False
# 3648      False
# 3811      False
# 3862      False
# 4099      False
# 4212      False
# 4314      False
# 4315      False
# 5980      False
# 5981      False
# 6040      False
# 6346      False
# 6357      False
# 6370      False
# 6757      False
# 6785      False
# 6789      False
# 6803      False
# 6821      False
# Among the genes that produced 0 hits, where there any genes that would be identified as variable by nBF > 1?
#      locus_name           BF        FC      nBF_WT  AOTP_WT    nBF_Snf2  \
# 56       RUF5-1    -1.191579  0.080133  232.720615     True    4.230186
# 57       RUF5-2    -3.139384  0.077677  105.653391     True  -93.026862
# 59         SRG1   365.733360 -0.939803    1.190075     True -141.263713
# 60         TLC1   777.763124  0.472738  284.895344     True  178.488220
# 63      YAL003W  6673.475968 -0.594133  954.663405     True  259.131618
# ...         ...          ...       ...         ...      ...         ...
# 6727    YPR187W    39.001492 -0.117950  100.066660     True -108.538938
# 6730    YPR190C    48.045047 -0.216275  135.716958     True -136.905959
# 6731    YPR191W   218.989419  0.279871  251.986788     True  -38.705868
# 6761      snR30    20.556922  0.159709    2.616569     True   85.355966
# 6824      snR86   272.275536  0.372995  120.984196     True  160.053022
#
#       AOTP_Snf2
# 56         True
# 57        False
# 59        False
# 60         True
# 63         True
# ...         ...
# 6727      False
# 6730      False
# 6731      False
# 6761       True
# 6824       True
#
# [1578 rows x 7 columns]

# %%
# Comparison whether bootstrapping BF for consistency identify the same genes as the control experiments

# Importing the results from explore_clean_yeast_consistency.ipynb

RALL_bayexpress_AOTP_WT_union = pd.read_csv('RALL_bayexpress_AOTP_WT_union.csv', index_col=0)

display(RALL_bayexpress_AOTP_WT_union)

# all genes identified by boostrapping BF for consistency are producing hits, but not all hit producing genes are identified by bootstrapping BF for consistency
display(CONTROL_R10_bayexpress_FC0.loc[CONTROL_R10_bayexpress_FC0.Ntrue > 0].loc[RALL_bayexpress_AOTP_WT_union.index])
# Out:
#      locus_name          BF        FC      nBF_WT  AOTP_WT     nBF_Snf2  \
# 1      21S_rRNA   -1.302642  0.147177  362.115507     True  1052.203968
# 4          LSR1    0.451012  0.120243  251.787125     True   478.066414
# 41       RDN5-1   13.774601  0.316040  246.914584     True   521.186933
# 46       RDN5-6   15.230943  0.469612  172.850686     True   347.304031
# 56       RUF5-1   -1.191579  0.080133  232.720615     True     4.230186
# ...         ...         ...       ...         ...      ...          ...
# 6731    YPR191W  218.989419  0.279871  251.986788     True   -38.705868
# 6745    YPR204W  814.266672  0.541523   -1.746145     True    37.268866
# 6752     snR17a    7.383833  0.329308   28.421292     True   239.879652
# 6761      snR30   20.556922  0.159709    2.616569     True    85.355966
# 6824      snR86  272.275536  0.372995  120.984196     True   160.053022
#
#       AOTP_Snf2
# 1          True
# 4          True
# 41         True
# 46         True
# 56         True
# ...         ...
# 6731      False
# 6745       True
# 6752       True
# 6761       True
# 6824       True
#
# [1633 rows x 7 columns]
#      locus_name      1     2      3      4      5      6      7      8      9  \
# 1      21S_rRNA  False  True  False   True   True  False   True  False   True
# 4          LSR1  False  True  False  False  False  False  False  False   True
# 41       RDN5-1  False  True  False  False   True   True  False  False   True
# 46       RDN5-6   True  True  False  False   True   True  False  False   True
# 56       RUF5-1  False  True   True   True   True   True  False   True   True
# ...         ...    ...   ...    ...    ...    ...    ...    ...    ...    ...
# 6731    YPR191W  False  True  False  False  False  False   True   True  False
# 6745    YPR204W   True  True   True  False  False   True  False   True  False
# 6752     snR17a  False  True  False  False  False  False  False  False   True
# 6761      snR30   True  True  False  False  False  False  False  False   True
# 6824      snR86  False  True  False  False   True   True   True   True   True
#
#       ...     92     93     94     95     96     97     98     99    100  \
# 1     ...   True   True  False  False   True  False   True  False   True
# 4     ...   True   True  False  False   True  False   True  False   True
# 41    ...  False   True  False  False  False  False  False  False   True
# 46    ...  False   True  False  False  False  False  False  False   True
# 56    ...  False   True  False  False  False  False   True   True  False
# ...   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6731  ...  False   True  False  False  False   True   True  False   True
# 6745  ...  False   True  False  False   True  False   True  False  False
# 6752  ...  False   True  False  False  False  False   True  False   True
# 6761  ...   True   True  False  False  False  False  False  False   True
# 6824  ...  False  False  False  False  False  False   True  False  False
#
#       Ntrue
# 1        53
# 4        53
# 41       43
# 46       48
# 56       54
# ...     ...
# 6731     47
# 6745     39
# 6752     33
# 6761     25
# 6824     38
#
# [1633 rows x 102 columns]
